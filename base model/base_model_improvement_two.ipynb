# %% [markdown]
# <a href="https://colab.research.google.com/github/mingrui-liu/Hyperpigmentation-autograde/blob/main/base_model_improvement_two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
import os
import shutil
import random
import pandas as pd
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import numpy as np

import tensorflow_addons as tfa
from tensorflow.keras.optimizers import SGD,Adam,RMSprop,Nadam
from sklearn.model_selection import train_test_split

# %%
# connect to your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 32
IMG_SIZE = 512

# %%
#Create image tf dataset from directory 
AUTOTUNE = tf.data.experimental.AUTOTUNE
  
def load_and_preprocess_image(path):
  image = tf.io.read_file(path)
  image = tf.image.decode_jpeg(image, channels=3)
  image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
  image = tf.clip_by_value(image, 0.0, 255.0)
  image = tf.cast(image, dtype=tf.uint8)
  return image



all_image_paths_1 = sorted(glob.glob("/content/drive/My Drive/Unilever/image_test/*.jpg"))
all_image_paths_2 = sorted(glob.glob("/content/drive/My Drive/Unilever/Additional_Images/*.jpg"))

# read the excel file
MHPgrades = pd.read_excel("/content/drive/My Drive/Unilever/MHPgrades.xlsx",header = 0)
MHPgrades2 = pd.read_excel("/content/drive/My Drive/Unilever/SKN-APP-0452-MHPgrades.xlsx",header = 1)

MHPgrades2 = MHPgrades2.dropna(axis = 0)
MHPgrades2 = MHPgrades2.melt(id_vars=["Subject No.", "Side of Face"], 
        var_name="VISIT", 
        value_name="Mottled hyperpigmentation").sort_values(by = ['Subject No.','Side of Face'])

grade1 = MHPgrades["Mottled hyperpigmentation"]

#Manipulate excel file
MHPgrades2.loc[MHPgrades2['VISIT'] == 'Baseline' , 'VISIT'] = '00'
MHPgrades2.loc[MHPgrades2['VISIT'] == 'Week 4' , 'VISIT'] = '04'
MHPgrades2.loc[MHPgrades2['VISIT'] == 'Week 8' , 'VISIT'] = '08'
MHPgrades2.loc[MHPgrades2['VISIT'] == 'Week 12' , 'VISIT'] = '12'
MHPgrades2.loc[MHPgrades2['VISIT'] == 'Week 16' , 'VISIT'] = '16'
MHPgrades2.loc[MHPgrades2['VISIT'] == 'Week 17' , 'VISIT'] = '17'

MHPgrades2.loc[MHPgrades2['Side of Face'] == 'Left' , 'Side of Face'] = 'L'
MHPgrades2.loc[MHPgrades2['Side of Face'] == 'Right' , 'Side of Face'] = 'R'

# %%
#match grade and images and make valid pair
valid_path = []
valid_label = []
for index, row in MHPgrades2.iterrows():
    id = str(row['Subject No.'] )
    id = id.zfill(4)

    side = row['Side of Face']
   
    visit = str(row['VISIT'])

    grade = row['Mottled hyperpigmentation']
  


    output = [path for path in all_image_paths_2 if path.startswith('/content/drive/My Drive/Unilever/Additional_Images/P' + id + '_FACE_' + side + '_S00_VCR_S2_V00D00W' + visit)] 
    if len(output)>0:
      valid_path.append(output[0])
      valid_label.append(grade)

all_image_paths = all_image_paths_1 + valid_path
all_image_labels = list(grade1) +  valid_label
print(len(all_image_labels ))
print(len(all_image_paths))


##Create label and zip dataset
all_label = []
for grade in all_image_labels:
  if grade < 3.0:
    label = 2.5
  elif grade > 5.0:
    label = 5.5
  else:
    label = grade
  all_label.append(label)

label_to_index = dict((name, index) for index, name in enumerate(sorted(set(all_label))))
all_labels = [label_to_index[grade] for grade in all_label]

##train val test split
train_paths, test_paths, train_labels, test_labels = train_test_split(all_image_paths, all_labels, test_size=0.1, random_state=1)

train_paths, val_paths, train_labels, val_labels = train_test_split(train_paths, train_labels, test_size=0.1, random_state=1)

path_ds = tf.data.Dataset.from_tensor_slices(train_paths)
image_ds = path_ds.map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
DATASET_SIZE = len(image_ds)
label_ds = tf.data.Dataset.from_tensor_slices(tf.cast(train_labels, tf.float32))

# a dataset that returns images and labels
image_label_ds = tf.data.Dataset.zip((image_ds, label_ds))
# Out:
# 2403
# 2403

# %%
## plot
label = sorted(pd.DataFrame(all_image_labels)[0].unique())
for g in label:
    count = 0
    for i in range(len(all_image_labels)):
      if all_image_labels[i] == g:
        count = count+1
    print('grade ', g, ' has ', count)
  # grades 0.5, 1.0, 1.5 --> low
  # grades 4.5, 5.0, 5.5, 6.0 --> high

  plt.hist(all_image_labels,bins = 14)

# %% [markdown]
# using generator

# %%
def normalize(x):
  x /= 127.5
  x -= 1.
  return x
  
# here's our final training dataset
train_ds = image_label_ds.cache()
train_ds = train_ds.shuffle(buffer_size = 1024)
train_ds = train_ds.repeat()
train_ds = train_ds.map(lambda image, label: (tf.image.random_flip_left_right(image),label),num_parallel_calls=AUTOTUNE)

#train_ds = train_ds.map(lambda image,label:(randaugment.distort_image_with_randaugment(image,num_layers = 2,magnitude = 2),label),num_parallel_calls=AUTOTUNE)
train_ds = train_ds.map(lambda image,label:(normalize(tf.cast(image,tf.float32)),label),num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)

#validation dataset
val_path_ds = tf.data.Dataset.from_tensor_slices(val_paths)
val_image_ds = val_path_ds.map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
val_label_ds = tf.data.Dataset.from_tensor_slices(tf.cast(val_labels, tf.float32))
val_ds = tf.data.Dataset.zip((val_image_ds, val_label_ds))
val_ds= val_ds.map(lambda image,label:(normalize(tf.cast(image,tf.float32)),label),num_parallel_calls=AUTOTUNE)
val_ds = val_ds.cache().batch(BATCH_SIZE)

#test dataset
test_path_ds = tf.data.Dataset.from_tensor_slices(test_paths)
test_image_ds =test_path_ds.map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
test_label_ds = tf.data.Dataset.from_tensor_slices(tf.cast(test_labels, tf.float32))
test_ds = tf.data.Dataset.zip((test_image_ds, test_label_ds))
test_ds= test_ds.map(lambda image,label:(normalize(tf.cast(image,tf.float32)),label),num_parallel_calls=AUTOTUNE)
test_ds = test_ds.cache().batch(BATCH_SIZE)

# %% [markdown]
# #### Transfer Learning

# %%
from tensorflow.keras.applications import ResNet50

base_model = ResNet50(include_top = False, weights = 'imagenet', 
                         input_shape = (IMG_SIZE, IMG_SIZE, 3))



for layer in base_model.layers[:160]:
  layer.trainable = False

drop_out = tf.keras.layers.Dropout(.3, input_shape =(24, 16, 16,2048))
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
prediction_layer = tf.keras.layers.Dense(7, activation='softmax')

# build a new model reusing the pretrained base
model = tf.keras.Sequential([
  base_model,
  drop_out,
  global_average_layer,
  prediction_layer
])


lr_schedule  = tfa.optimizers.ExponentialCyclicalLearningRate(
                              initial_learning_rate=1e-8,
                              maximal_learning_rate=1e-4,
                              step_size=240,
                              )
opt = Adam(learning_rate=lr_schedule)

model.compile(optimizer= opt,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_ds,
      epochs = 50,
      steps_per_epoch = 30,
      validation_data = val_ds)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 40s 1s/step - loss: 2.1086 - accuracy: 0.1583 - val_loss: 1.9737 - val_accuracy: 0.2535
# Epoch 2/50
# 30/30 [==============================] - 21s 688ms/step - loss: 1.8564 - accuracy: 0.2958 - val_loss: 2.0267 - val_accuracy: 0.1889
# Epoch 3/50
# 30/30 [==============================] - 20s 665ms/step - loss: 1.7364 - accuracy: 0.3438 - val_loss: 1.9961 - val_accuracy: 0.1797
# Epoch 4/50
# 30/30 [==============================] - 20s 651ms/step - loss: 1.7157 - accuracy: 0.3198 - val_loss: 1.9825 - val_accuracy: 0.1843
# Epoch 5/50
# 30/30 [==============================] - 20s 661ms/step - loss: 1.6445 - accuracy: 0.3521 - val_loss: 1.8316 - val_accuracy: 0.2212
# Epoch 6/50
# 30/30 [==============================] - 20s 672ms/step - loss: 1.6068 - accuracy: 0.3844 - val_loss: 1.9030 - val_accuracy: 0.2488
# Epoch 7/50
# 30/30 [==============================] - 20s 668ms/step - loss: 1.5224 - accuracy: 0.4260 - val_loss: 2.1327 - val_accuracy: 0.1659
# Epoch 8/50
# 30/30 [==============================] - 20s 662ms/step - loss: 1.5391 - accuracy: 0.4073 - val_loss: 1.8513 - val_accuracy: 0.2995
# Epoch 9/50
# 30/30 [==============================] - 20s 665ms/step - loss: 1.4319 - accuracy: 0.4563 - val_loss: 1.9682 - val_accuracy: 0.2442
# Epoch 10/50
# 30/30 [==============================] - 20s 661ms/step - loss: 1.4139 - accuracy: 0.4583 - val_loss: 1.7782 - val_accuracy: 0.3364
# Epoch 11/50
# 30/30 [==============================] - 20s 666ms/step - loss: 1.2695 - accuracy: 0.5385 - val_loss: 1.8150 - val_accuracy: 0.2857
# Epoch 12/50
# 30/30 [==============================] - 20s 671ms/step - loss: 1.2518 - accuracy: 0.5458 - val_loss: 1.8013 - val_accuracy: 0.3226
# Epoch 13/50
# 30/30 [==============================] - 20s 669ms/step - loss: 1.0757 - accuracy: 0.6479 - val_loss: 1.8594 - val_accuracy: 0.2811
# Epoch 14/50
# 30/30 [==============================] - 20s 665ms/step - loss: 1.0854 - accuracy: 0.6125 - val_loss: 1.7771 - val_accuracy: 0.3456
# Epoch 15/50
# 30/30 [==============================] - 20s 664ms/step - loss: 0.9657 - accuracy: 0.6833 - val_loss: 1.5742 - val_accuracy: 0.3871
# Epoch 16/50
# 30/30 [==============================] - 20s 662ms/step - loss: 0.9301 - accuracy: 0.7052 - val_loss: 1.6059 - val_accuracy: 0.3871
# Epoch 17/50
# 30/30 [==============================] - 20s 666ms/step - loss: 0.8975 - accuracy: 0.7177 - val_loss: 1.5869 - val_accuracy: 0.3917
# Epoch 18/50
# 30/30 [==============================] - 20s 669ms/step - loss: 0.9194 - accuracy: 0.7000 - val_loss: 1.6150 - val_accuracy: 0.4055
# Epoch 19/50
# 30/30 [==============================] - 20s 671ms/step - loss: 0.8822 - accuracy: 0.7208 - val_loss: 1.8555 - val_accuracy: 0.3226
# Epoch 20/50
# 30/30 [==============================] - 20s 671ms/step - loss: 0.8996 - accuracy: 0.7094 - val_loss: 2.1846 - val_accuracy: 0.2719
# Epoch 21/50
# 30/30 [==============================] - 20s 667ms/step - loss: 0.8877 - accuracy: 0.7208 - val_loss: 1.9526 - val_accuracy: 0.2765
# Epoch 22/50
# 30/30 [==============================] - 20s 664ms/step - loss: 0.8802 - accuracy: 0.6979 - val_loss: 1.9565 - val_accuracy: 0.3364
# Epoch 23/50
# 30/30 [==============================] - 20s 664ms/step - loss: 0.8451 - accuracy: 0.7344 - val_loss: 2.2663 - val_accuracy: 0.2581
# Epoch 24/50
# 30/30 [==============================] - 20s 668ms/step - loss: 0.8885 - accuracy: 0.6979 - val_loss: 3.5008 - val_accuracy: 0.3041
# Epoch 25/50
# 30/30 [==============================] - 20s 672ms/step - loss: 0.8341 - accuracy: 0.7031 - val_loss: 2.1570 - val_accuracy: 0.3963
# Epoch 26/50
# 30/30 [==============================] - 20s 672ms/step - loss: 0.8055 - accuracy: 0.7094 - val_loss: 2.6412 - val_accuracy: 0.2949
# Epoch 27/50
# 30/30 [==============================] - 20s 669ms/step - loss: 0.6499 - accuracy: 0.7844 - val_loss: 2.0751 - val_accuracy: 0.3456
# Epoch 28/50
# 30/30 [==============================] - 20s 665ms/step - loss: 0.5522 - accuracy: 0.8427 - val_loss: 1.7273 - val_accuracy: 0.4378
# Epoch 29/50
# 30/30 [==============================] - 20s 663ms/step - loss: 0.4842 - accuracy: 0.8677 - val_loss: 1.9494 - val_accuracy: 0.3825
# Epoch 30/50
# 30/30 [==============================] - 20s 670ms/step - loss: 0.4091 - accuracy: 0.8969 - val_loss: 2.0233 - val_accuracy: 0.4147
# Epoch 31/50
# 30/30 [==============================] - 20s 668ms/step - loss: 0.3455 - accuracy: 0.9281 - val_loss: 1.7961 - val_accuracy: 0.4009
# Epoch 32/50
# 30/30 [==============================] - 20s 671ms/step - loss: 0.2982 - accuracy: 0.9490 - val_loss: 1.8062 - val_accuracy: 0.3825
# Epoch 33/50
# 30/30 [==============================] - 20s 666ms/step - loss: 0.2761 - accuracy: 0.9563 - val_loss: 1.8452 - val_accuracy: 0.3871
# Epoch 34/50
# 30/30 [==============================] - 20s 661ms/step - loss: 0.2896 - accuracy: 0.9521 - val_loss: 1.8454 - val_accuracy: 0.3917
# Epoch 35/50
# 30/30 [==============================] - 20s 663ms/step - loss: 0.2759 - accuracy: 0.9479 - val_loss: 1.9043 - val_accuracy: 0.3871
# Epoch 36/50
# 30/30 [==============================] - 20s 671ms/step - loss: 0.3029 - accuracy: 0.9323 - val_loss: 2.2516 - val_accuracy: 0.3917
# Epoch 37/50
# 30/30 [==============================] - 20s 671ms/step - loss: 0.3003 - accuracy: 0.9375 - val_loss: 2.2950 - val_accuracy: 0.3226
# Epoch 38/50
# 30/30 [==============================] - 20s 671ms/step - loss: 0.3103 - accuracy: 0.9260 - val_loss: 3.4054 - val_accuracy: 0.3041
# Epoch 39/50
# 30/30 [==============================] - 20s 668ms/step - loss: 0.3540 - accuracy: 0.9042 - val_loss: 3.0002 - val_accuracy: 0.3410
# Epoch 40/50
# 30/30 [==============================] - 20s 663ms/step - loss: 0.3769 - accuracy: 0.9021 - val_loss: 2.7289 - val_accuracy: 0.3364
# Epoch 41/50
# 30/30 [==============================] - 20s 665ms/step - loss: 0.4288 - accuracy: 0.8604 - val_loss: 3.8979 - val_accuracy: 0.3226
# Epoch 42/50
# 30/30 [==============================] - 20s 667ms/step - loss: 0.3679 - accuracy: 0.9000 - val_loss: 2.6869 - val_accuracy: 0.3687
# Epoch 43/50
# 30/30 [==============================] - 20s 671ms/step - loss: 0.3041 - accuracy: 0.9135 - val_loss: 2.7790 - val_accuracy: 0.3364
# Epoch 44/50
# 30/30 [==============================] - 20s 672ms/step - loss: 0.2031 - accuracy: 0.9604 - val_loss: 2.3987 - val_accuracy: 0.3779
# Epoch 45/50
# 30/30 [==============================] - 20s 666ms/step - loss: 0.1535 - accuracy: 0.9781 - val_loss: 2.4498 - val_accuracy: 0.3594
# Epoch 46/50
# 30/30 [==============================] - 20s 663ms/step - loss: 0.1216 - accuracy: 0.9833 - val_loss: 2.1391 - val_accuracy: 0.3963
# Epoch 47/50
# 30/30 [==============================] - 20s 670ms/step - loss: 0.0936 - accuracy: 0.9937 - val_loss: 2.1080 - val_accuracy: 0.4332
# Epoch 48/50
# 30/30 [==============================] - 20s 670ms/step - loss: 0.0745 - accuracy: 0.9969 - val_loss: 2.0867 - val_accuracy: 0.4194
# Epoch 49/50
# 30/30 [==============================] - 20s 666ms/step - loss: 0.0836 - accuracy: 0.9917 - val_loss: 2.1187 - val_accuracy: 0.4055
# Epoch 50/50
# 30/30 [==============================] - 20s 665ms/step - loss: 0.0728 - accuracy: 0.9958 - val_loss: 2.2515 - val_accuracy: 0.3871

# %% [markdown]
# ### Evaluate model

# %%
def plot(history):
  
    plt.title('Training and validation accuracy')
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.show()


    plt.figure()
    plt.title('Training and validation loss')
    plt.plot(history.history['loss'][7:], label='loss')
    plt.plot(history.history['val_loss'][7:], label = 'val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='lower right')
    plt.show()

# %%
plot(history)

# %%
plot(history)

# %%
loss, accuracy = model.evaluate(test_ds)
print("Accuracy: {:2.2%}".format(accuracy))
# Out:
# 19/19 [==============================] - 5s 256ms/step - loss: 2.4354 - accuracy: 0.5042
# Accuracy: 50.42%

# %%
prediction = model.predict_classes(test_ds)
# Out:
# WARNING:tensorflow:From <ipython-input-24-a8fb5c0bdfac>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
classes=[0,1,2,3,4,5,6]
con_mat  = tf.math.confusion_matrix(
    test_labels, prediction, num_classes=None, weights=None, dtype=tf.dtypes.int32,
    name=None
).numpy()
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)

con_mat_df = pd.DataFrame(con_mat_norm,
                     index = classes, 
                     columns = classes)

# %%
import seaborn as sns
figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
